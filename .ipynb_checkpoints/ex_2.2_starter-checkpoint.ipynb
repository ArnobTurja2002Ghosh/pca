# %% [markdown]
# # Frequent Itemset and Association Rules Mining using Apriori Algorithm
#
# In this part, you will build a system which can help make recommendations using the Apriori algorithm.
#
# To solve this assignment you will need to go though these pages:
#
# * https://rasbt.github.io/mlxtend/user_guide/preprocessing/TransactionEncoder/
# * https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/
# * https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/
# * https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/fpgrowth/
#
# The `apply` function in `pandas` can prove very useful for this assignment. See https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html
#
# **Source**: Online Retail. (2015). UCI Machine Learning Repository. https://doi.org/10.24432/C5BW33.

# %%
import pandas as pd
# !pip install mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# Requirement already satisfied: mlxtend in c:\users\arnob\anaconda3\lib\site-packages (0.23.1)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\arnob\anaconda3\lib\site-packages (from mlxtend) (1.11.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\arnob\anaconda3\lib\site-packages (from mlxtend) (1.24.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\arnob\anaconda3\lib\site-packages (from mlxtend) (2.0.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\arnob\anaconda3\lib\site-packages (from mlxtend) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\arnob\anaconda3\lib\site-packages (from mlxtend) (3.7.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\arnob\anaconda3\lib\site-packages (from mlxtend) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arnob\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\arnob\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arnob\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\arnob\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\arnob\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\arnob\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\arnob\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\arnob\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arnob\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\arnob\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\arnob\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\arnob\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %% [markdown]
# ## Load and Inspect Data

# %%
invoices = pd.read_csv('apriori_data.csv')
invoices.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ## Data Transformation
#
# Drop everything except InvoiceNo and StockCode since we can use InvoiceNo for transaction id and StockCode for item name

# %%
# Your code here
data=invoices[['InvoiceNo', 'StockCode']]
data
# Out:
#        InvoiceNo StockCode
# 0         536365    85123A
# 1         536365     71053
# 2         536365    84406B
# 3         536365    84029G
# 4         536365    84029E
# ...          ...       ...
# 541904    581587     22613
# 541905    581587     22899
# 541906    581587     23254
# 541907    581587     23255
# 541908    581587     22138
#
# [541909 rows x 2 columns]

# %%
data.head()
# Out:
#   InvoiceNo StockCode
# 0    536365    85123A
# 1    536365     71053
# 2    536365    84406B
# 3    536365    84029G
# 4    536365    84029E

# %% [markdown]
# Group the data by InvoiceNo and create a list of StockCode for each invoice

# %%
# Your code here
transactions=list(data.groupby(by='InvoiceNo')['StockCode'].apply(list).reset_index()['StockCode'])

# %%
transactions[0:4]
# Out:
# [['85123A', '71053', '84406B', '84029G', '84029E', '22752', '21730'],
#  ['22633', '22632'],
#  ['84879',
#   '22745',
#   '22748',
#   '22749',
#   '22310',
#   '84969',
#   '22623',
#   '22622',
#   '21754',
#   '21755',
#   '21777',
#   '48187'],
#  ['22960', '22913', '22912', '22914']]

# %% [markdown]
# Using TransactionEncoder, convert the transactions into a dataset where each row represents a transaction and each column represents an item. The values will be True or False depending on whether the item is present in that specific transaction.

# %%
# Your code here
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
transactions_df=pd.DataFrame(te_ary, columns=te.columns_)

# %%
transactions_df.head()
# Out:
#    10002  10080  10120  10123C  10123G  10124A  10124G  10125  10133  10134  \
# 0  False  False  False   False   False   False   False  False  False  False
# 1  False  False  False   False   False   False   False  False  False  False
# 2  False  False  False   False   False   False   False  False  False  False
# 3  False  False  False   False   False   False   False  False  False  False
# 4  False  False  False   False   False   False   False  False  False  False
#
#    ...      M   PADS   POST      S  gift_0001_10  gift_0001_20  gift_0001_30  \
# 0  ...  False  False  False  False         False         False         False
# 1  ...  False  False  False  False         False         False         False
# 2  ...  False  False  False  False         False         False         False
# 3  ...  False  False  False  False         False         False         False
# 4  ...  False  False  False  False         False         False         False
#
#    gift_0001_40  gift_0001_50      m
# 0         False         False  False
# 1         False         False  False
# 2         False         False  False
# 3         False         False  False
# 4         False         False  False
#
# [5 rows x 4070 columns]

# %% [markdown]
# ## Use Apriori to get the frequent itemsets and inspect the results
#
# Use apriori to find the frequent_itemsets for `min_sup` = `1%`

# %%
# Your code here
transactions_df['sup']=transactions_df.sum(axis=1)
transactions_df[transactions_df['sup']/len(transactions_df['sup']) >= 0.01]
# Out:
#        10002  10080  10120  10123C  10123G  10124A  10124G  10125  10133  \
# 84     False  False  False   False   False   False   False  False  False
# 131    False  False  False   False   False   False   False  False  False
# 298     True  False  False   False   False   False   False  False   True
# 479    False  False  False   False   False   False   False  False  False
# 482     True  False  False   False   False   False   False   True  False
# ...      ...    ...    ...     ...     ...     ...     ...    ...    ...
# 21753  False  False  False   False   False   False   False  False  False
# 21895  False  False  False   False   False   False   False  False  False
# 21897  False  False  False   False   False   False   False  False  False
# 21994  False  False  False   False   False   False   False  False  False
# 22032  False  False  False   False   False   False   False  False  False
#
#        10134  ...   PADS   POST      S  gift_0001_10  gift_0001_20  \
# 84     False  ...  False  False  False         False         False
# 131    False  ...  False  False  False         False         False
# 298    False  ...  False  False  False         False         False
# 479    False  ...  False  False  False         False         False
# 482    False  ...  False  False  False         False         False
# ...      ...  ...    ...    ...    ...           ...           ...
# 21753  False  ...  False  False  False         False         False
# 21895  False  ...  False  False  False          True         False
# 21897  False  ...  False  False  False         False         False
# 21994  False  ...  False  False  False         False         False
# 22032  False  ...  False  False  False         False         False
#
#        gift_0001_30  gift_0001_40  gift_0001_50      m  sup
# 84            False         False         False  False  523
# 131           False         False         False  False  590
# 298           False         False         False  False  586
# 479           False         False         False  False  595
# 482           False         False         False  False  568
# ...             ...           ...           ...    ...  ...
# 21753         False         False         False  False  629
# 21895         False         False         False  False  676
# 21897         False         False         False  False  749
# 21994         False         False         False  False  635
# 22032         False         False         False  False  731
#
# [148 rows x 4071 columns]

# %%
frequent_itemsets.shape
# Out:
# (1087, 2)

# %%
frequent_itemsets.head()
# Out:
#     support   itemsets
# 0  0.020193    (15036)
# 1  0.012587  (15056BL)
# 2  0.017876   (15056N)
# 3  0.011236    (16237)
# 4  0.012510    (20675)

# %% [markdown]
# Add an additional column called `items_count` to the dataframe which represents the number of items in the itemset.

# %%
# Your code here

# %%
frequent_itemsets.head()
# Out:
#     support   itemsets  items_count
# 0  0.020193    (15036)            1
# 1  0.012587  (15056BL)            1
# 2  0.017876   (15056N)            1
# 3  0.011236    (16237)            1
# 4  0.012510    (20675)            1

# %% [markdown]
# Display the various itemsets generated sorted (descending) by the items_count.

# %%
# Your code here
# Out:
#        support                       itemsets  items_count
# 1086  0.011699   (22697, 22699, 22423, 22698)            4
# 1085  0.010386  (22386, 22411, 21931, 85099B)            4
# 1084  0.010077   (20719, 20723, 20724, 22355)            4
# 1032  0.012548          (22384, 20725, 20728)            3
# 1024  0.011042          (22384, 20726, 20725)            3

# %% [markdown]
# Show how many itemsets exist by items_count

# %%
# Your code here

# %% [markdown]
# ## Generate association rules
# Generate all association rules using the `lift` metric with a minimum value of 2

# %%
# Your code here

# %%
rules.shape
# Out:
# (1338, 10)

# %%
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0     (20712)     (20711)            0.033668            0.020541  0.011158
# 1     (20711)     (20712)            0.020541            0.033668  0.011158
# 2     (21931)     (20711)            0.046371            0.020541  0.011506
# 3     (20711)     (21931)            0.020541            0.046371  0.011506
# 4     (22386)     (20711)            0.047529            0.020541  0.010888
#
#    confidence       lift  leverage  conviction  zhangs_metric
# 0    0.331422  16.135019  0.010467    1.464989       0.970705
# 1    0.543233  16.135019  0.010467    2.115591       0.957695
# 2    0.248127  12.079846  0.010553    1.302692       0.961818
# 3    0.560150  12.079846  0.010553    2.168080       0.936453
# 4    0.229082  11.152679  0.009912    1.270511       0.955762

# %%
invoices.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# Add the names of the items back in the data frame as save all rules in a csv file

# %%
# Your code here

# %%
rules.head()
# Out:
#   antecedents consequents  antecedent support  consequent support   support  \
# 0     (20712)     (20711)            0.033668            0.020541  0.011158
# 1     (20711)     (20712)            0.020541            0.033668  0.011158
# 2     (21931)     (20711)            0.046371            0.020541  0.011506
# 3     (20711)     (21931)            0.020541            0.046371  0.011506
# 4     (22386)     (20711)            0.047529            0.020541  0.010888
#
#    confidence       lift  leverage  conviction  zhangs_metric  \
# 0    0.331422  16.135019  0.010467    1.464989       0.970705
# 1    0.543233  16.135019  0.010467    2.115591       0.957695
# 2    0.248127  12.079846  0.010553    1.302692       0.961818
# 3    0.560150  12.079846  0.010553    2.168080       0.936453
# 4    0.229082  11.152679  0.009912    1.270511       0.955762
#
#          antecedents_desciption       consequents_description
# 0  [JUMBO BAG WOODLAND ANIMALS]             [JUMBO BAG TOYS ]
# 1             [JUMBO BAG TOYS ]  [JUMBO BAG WOODLAND ANIMALS]
# 2      [JUMBO STORAGE BAG SUKI]             [JUMBO BAG TOYS ]
# 3             [JUMBO BAG TOYS ]      [JUMBO STORAGE BAG SUKI]
# 4     [JUMBO BAG PINK POLKADOT]             [JUMBO BAG TOYS ]

# %%
rules.shape
# Out:
# (1338, 12)

# %%
# I used the following line to create the rules_100.csv file which only gives you 100 rules.
# rules.sample(100).to_csv('rules_100.csv', index=False)

# You must submit the rules.csv file that contains all the 1338 rules by running the following command
rules.to_csv('rules.csv', index=False)
